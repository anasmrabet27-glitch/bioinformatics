# %%
from Bio import SeqIo
record = SeqIO.read("Sequence.fasta", "fasta")
print("ID:", record.id)
print("Description:", record.description)
print("longueur:", len(record.seq))

#lire plusieurs séquences:
from Bio import SeqIO
for record in SeqIO.parse("sequences.fasta", "fasta"):

#creer une variable ADN pour faciliter
ADN = record.seq

# %% [markdown]
# ## lire fichier fasta
# 'SeqIO.read ' permet de lire une seule séquence à partir d'un fichier FASTA. l'objet record contient les informations sur cette séquence. alors que 'SeqIO' permet de lire plusieurs séquences.
